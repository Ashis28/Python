# %% [markdown]
# ### Creating a text file

# %%
ls
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 9490-4245
#
#  Directory of C:\Users\ashis\OneDrive - Lovely Professional University\Documents\Gfg\OSanaconda
#
# 04-06-2024  19:43    <DIR>          .
# 04-06-2024  17:35    <DIR>          ..
# 04-06-2024  19:43    <DIR>          .ipynb_checkpoints
# 04-06-2024  19:42            26,834 1DataRead.ipynb
# 04-06-2024  19:42                72 2WriteDataInTxtFile.ipynb
# 04-06-2024  18:30             1,043 Data.txt
#                3 File(s)         27,949 bytes
#                3 Dir(s)  359,243,153,408 bytes free

# %%
fd = open("Data2.txt",'a')
fd.write("And its preety Cool Stuff \n")
fd.close()

# %% [markdown]
# ### Writing data in a text file in new line in append mode

# %%
fd = open("Data2.txt",'a')
txt = input("Enter some context ")
txt = txt + '.\n'
fd.write(txt)
fd.close()
# Out:
# Enter some context  I am ahsi and i am learing data science
