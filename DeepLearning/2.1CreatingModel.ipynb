# %% [markdown]
# #### Creating a model for 2 hidden layer network

# %%
input_size = 3

layers = [3,2]

output_size = 2

# %%
layers
# Out:
# [3, 2]

# %%
import numpy as np

# %%
class NeuralNetwork:
    def __init__(self,input_size,layers,output_size):
        np.random.seed(0)
        w1 = np.radnom.randn(input_size,layers[0])
        w2 = np.random.randn(layers[1],output_size)

# %%
w2 = np.random.randn(layers[1],output_size)
w2
# Out:
# array([[-0.84430697,  0.19180699],
#        [ 0.62050293,  0.22810819]])

# %%
class NeuralNetwork:
    def __init__(self,input_size,layers,output_size):
        np.random.seed(0)

        model = {} #just created a dictionary
        
        model['w1'] = np.radnom.randn(input_size,layers[0])
        model['b1'] = np.zeros(1,layers[0])
        
        w2 = np.random.randn(layers[1],output_size)
        model['b1'] = np.zeros(1,output_size)

        self.model = model

# %%
np.zeros(1,layers[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 np.zeros(1,layers[0])
#
# TypeError: Cannot interpret '3' as a data type
