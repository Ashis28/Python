# %% [markdown]
# #### Detect Malarial cells using CNN

# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/39.5 MB 1.3 MB/s eta 0:00:30
#    ---------------------------------------- 0.1/39.5 MB 1.6 MB/s eta 0:00:25
#    ---------------------------------------- 0.2/39.5 MB 1.5 MB/s eta 0:00:27
#    ---------------------------------------- 0.3/39.5 MB 1.6 MB/s eta 0:00:26
#    ---------------------------------------- 0.3/39.5 MB 1.6 MB/s eta 0:00:26
#    ---------------------------------------- 0.4/39.5 MB 1.5 MB/s eta 0:00:26
#     --------------------------------------- 0.5/39.5 MB 1.6 MB/s eta 0:00:25
#     --------------------------------------- 0.6/39.5 MB 1.6 MB/s eta 0:00:25
#     --------------------------------------- 0.6/39.5 MB 1.6 MB/s eta 0:00:25
#     --------------------------------------- 0.7/39.5 MB 1.6 MB/s eta 0:00:25
#     --------------------------------------- 0.8/39.5 MB 1.6 MB/s eta 0:00:25
# ...

# %%
# !pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/49.8 kB ? eta -:--:--
#      -------------------------------- ------- 41.0/49.8 kB 1.9 MB/s eta 0:00:01
#      ---------------------------------------- 49.8/49.8 kB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/375.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/375.9 MB 1.7 MB/s eta 0:03:48
#    ---------------------------------------- 0.1/375.9 MB 1.7 MB/s eta 0:03:41
#    ---------------------------------------- 0.2/375.9 MB 1.7 MB/s eta 0:03:39
#    ---------------------------------------- 0.3/375.9 MB 1.6 MB/s eta 0:03:54
#    ---------------------------------------- 0.4/375.9 MB 1.6 MB/s eta 0:03:50
#    ---------------------------------------- 0.5/375.9 MB 1.7 MB/s eta 0:03:46
#    ---------------------------------------- 0.5/375.9 MB 1.7 MB/s eta 0:03:45
#    ---------------------------------------- 0.6/375.9 MB 1.6 MB/s eta 0:03:53
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os #to look in to the files we have in our server
import cv2

from PIL import Image

from tensorflow import keras
import tensorflow.keras.layers as k

# %% [raw]
# How to Visualize the images in code or show to the users

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from keras.preprocessing.image import ImageDataGenerator, load_img
#
# ImportError: cannot import name 'ImageDataGenerator' from 'keras.preprocessing.image' (C:\Users\ashis\anaconda3\Lib\site-packages\keras\api\preprocessing\image\__init__.py)

# %% [raw]
# Earlier versions of Keras were standalone, meaning you could install Keras as a separate package (pip install keras) and import things directly from keras.preprocessing.image.
#
# TensorFlow 2.x: Starting with TensorFlow 2.x, Keras was integrated directly into TensorFlow as a high-level API. Now, Keras is part of TensorFlow, and the recommended way is to use tensorflow.keras rather than keras as a standalone library.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

# %%
load_img("C:/Users/ashis/Downloads/archive (1).zip/Malarial Cell Image Data /cell_images/Parasitized")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 load_img("C:/Users/ashis/Downloads/archive (1).zip/Malarial Cell Image Data /cell_images/Parasitized")
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/ashis/Downloads/archive (1).zip/Malarial Cell Image Data /cell_images/Parasitized'

# %%
# Absolute path to the image
img_path = r"C:/Users/ashis/Downloads/Malarial Cell Image Data/cell_images/Parasitized/C33P1thinF_IMG_20150619_114756a_cell_179.png"

# Load the image with target size (resize if needed)
img = load_img(img_path, target_size=(64, 64))  # change size if needed
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 5
#       2 img_path = r"C:/Users/ashis/Downloads/Malarial Cell Image Data/cell_images/Parasitized/C33P1thinF_IMG_20150619_114756a_cell_179.png"
#       4 # Load the image with target size (resize if needed)
# ----> 5 img = load_img(img_path, target_size=(64, 64))
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/ashis/Downloads/Malarial Cell Image Data/cell_images/Parasitized/C33P1thinF_IMG_20150619_114756a_cell_179.png'

# %%
len("/kaggle/input/malarial-cell-image/Malarial Cell Image Data /malarial_cell_image_data/cell_images/cell_images/Parasitized")
# Out:
# 120

# %%
load_img("/kaggle/input/malarial-cell-image/Malarial Cell Image Data /cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_168.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 load_img("/kaggle/input/malarial-cell-image/Malarial Cell Image Data /cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_168.png")
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/malarial-cell-image/Malarial Cell Image Data /cell_images/Parasitized/C100P61ThinF_IMG_20150918_144104_cell_168.png'
